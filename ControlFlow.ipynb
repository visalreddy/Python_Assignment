# %% [markdown]
# <a href="https://colab.research.google.com/github/visalreddy/Python_Assignment/blob/main/ControlFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("What is your age?"))
eat_pizza=input("Do you eat Pizza?(yes/no)")
exer=input("Do you do exercise?(yes/no)")

if age < 30:
  if eat_pizza == "yes":
    print("You are unfit!!")
  else:
    print("You are fit!!")
else:
  if exer == "yes":
    print("You are fit!!")
  else:
    print("You are unfit!!")
# Out:
# What is your age?100
# Do you eat Pizza?(yes/no)no
# Do you do exercise?(yes/no)no
# You are unfit!!
