# %%
#What is the output of the following code

aTuple = (100, 200, 300, 400, 500)
aTuple[1] = 800
print(aTuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2666763352.py in <cell line: 0>()
#       2
#       3 aTuple = (100, 200, 300, 400, 500)
# ----> 4 aTuple[1] = 800
#       5 print(aTuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#What is the type of the following variable

aTuple = ("Orange")
print(type(aTuple))
# Out:
# <class 'str'>

# %%
#What is the output of the following

tuple1 = (1120,'a')
print(max(tuple1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-140302904.py in <cell line: 0>()
#       2
#       3 tuple1 = (1120,'a')
# ----> 4 print(max(tuple1))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
#What is the output of the following tuple operation

aTuple = (100,)
print(aTuple * 2)
# Out:
# (100, 100)

# %%
# What is the output of the following

aTuple = (10, 20, 30, 40, 50, 60, 70, 80)
print(aTuple[2:5], aTuple[:4], aTuple[3:])
# Out:
# (30, 40, 50) (10, 20, 30, 40) (40, 50, 60, 70, 80)

# %%
# What is the output of the following

aTuple = "Yellow", 20, "Red"
a, b, c = aTuple
print(a)
# Out:
# Yellow

# %%
# What is the output of the following tuple operation

aTuple = (100, 200, 300, 400, 500)
aTuple.pop(2)
print(aTuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2027678647.py in <cell line: 0>()
#       2
#       3 aTuple = (100, 200, 300, 400, 500)
# ----> 4 aTuple.pop(2)
#       5 print(aTuple)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
# Choose the correct way to access value 20 from the following tuple

aTuple = ("Orange", [10, 20, 30], (5, 15, 25))
print(aTuple[1][1])
# Out:
# 20
